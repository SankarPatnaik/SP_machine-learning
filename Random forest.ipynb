# %%
import pandas as pd
from sklearn import *
import numpy as np

df=pd.read_csv("/data/bank-full.csv",";")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.poutcome.value_counts()
# Out:
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64

# %%
 #dependent variable/target varible/label
label = "y"

# independepent variables/features/predictors
X = df.drop(columns=[label,"day","pdays"])

# vector for target variable
y = df[label]

# one hot encoding to conver categorical features into numeric
# drop_first: remove first value of a categorical feature ... it is redundant
X = pd.get_dummies(X, drop_first=True)

# Creating trainnig and test sets
# test_size is 30% of the whole
# random_state: to reprduce the same combination of training and test records
X_train, X_test, y_train, y_test = model_selection.train_test_split(X.values,                       
                                    y,  test_size = 0.3, random_state = 1)


pipe = pipeline.Pipeline([
    ("poly", preprocessing.PolynomialFeatures(degree=1, include_bias=False)),
    ("scaler", preprocessing.StandardScaler()),
    ("est", tree.DecisionTreeClassifier(max_depth=5, random_state=1))
])

pipe.fit(X_train, y_train)

# prediction on training and test data
y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

# %%
print(metrics.confusion_matrix(y_test,y_test_pred))
print("Training accuracy", metrics.accuracy_score(y_train, y_train_pred))
print("Test accuracy", metrics.accuracy_score(y_test, y_test_pred))
# Out:
# [[11725   288]
#  [ 1029   522]]
# Training accuracy 0.904098334755269
# Test accuracy 0.9029047478619876

# %%
est = pipe.steps[-1][-1]
est
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=1,
#             splitter='best')

# %%
from sklearn.tree import export_graphviz
export_graphviz(est, out_file = "tree.dot", feature_names = X.columns, filled=True)
# !dot -Tpng tree.dot -o tree.png
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.78949 to fit

# %%
importance = pd.DataFrame({"feature": X.columns
                , "importance":  est.feature_importances_})
importance.sort_values("importance", ascending=False)
# Out:
#                 feature  importance
# 2              duration    0.557299
# 38     poutcome_success    0.288661
# 0                   age    0.047522
# 32            month_mar    0.034552
# 35            month_oct    0.032319
# 25      contact_unknown    0.022191
# 33            month_may    0.005642
# 22          housing_yes    0.004479
# 20    education_unknown    0.001582
# 27            month_dec    0.001511
# 31            month_jun    0.001353
# 3              campaign    0.001096
# 34            month_nov    0.000923
# 1               balance    0.000871
# 9           job_retired    0.000000
# 7         job_housemaid    0.000000
# 37       poutcome_other    0.000000
# 36            month_sep    0.000000
# 4              previous    0.000000
# 5       job_blue-collar    0.000000
# 6      job_entrepreneur    0.000000
# 30            month_jul    0.000000
# 29            month_jan    0.000000
# 28            month_feb    0.000000
# 26            month_aug    0.000000
# 24    contact_telephone    0.000000
# 10    job_self-employed    0.000000
# 23             loan_yes    0.000000
# 8        job_management    0.000000
# 21          default_yes    0.000000
# 19   education_tertiary    0.000000
# 18  education_secondary    0.000000
# 17       marital_single    0.000000
# 16      marital_married    0.000000
# 15          job_unknown    0.000000
# 14       job_unemployed    0.000000
# 13       job_technician    0.000000
# 12          job_student    0.000000
# 11         job_services    0.000000
# 39     poutcome_unknown    0.000000

# %%
 #dependent variable/target varible/label
label = "y"

# independepent variables/features/predictors
X = df.drop(columns=[label,"day","pdays"])

# vector for target variable
y = df[label]

# one hot encoding to conver categorical features into numeric
# drop_first: remove first value of a categorical feature ... it is redundant
X = pd.get_dummies(X, drop_first=True)

# Creating trainnig and test sets
# test_size is 30% of the whole
# random_state: to reprduce the same combination of training and test records
X_train, X_test, y_train, y_test = model_selection.train_test_split(X.values,                       
                                    y,  test_size = 0.3, random_state = 1)


pipe = pipeline.Pipeline([
    ("poly", preprocessing.PolynomialFeatures(degree=1, include_bias=False)),
    ("scaler", preprocessing.StandardScaler()),
    ("est", ensemble.RandomForestClassifier(n_estimators=20,max_features=0.8
                                        , max_depth=10, random_state=1))
])

pipe.fit(X_train, y_train)

# prediction on training and test data
y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

# %%
est = pipe.steps[-1][-1]
est
est.estimators_
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1791095845, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=2135392491, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=946286476, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1857819720, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=491263, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=550290313, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1298508491, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=2143362693, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=630311759, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1013994432, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=396591248, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1703301249, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=799981516, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1666063943, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1484172013, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=729053692, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1704103302, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1870626073, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=166716594, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=0.8, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1487394068, splitter='best')]

# %%
importance = pd.DataFrame({"feature": X.columns
                , "importance":  est.feature_importances_})
importance.sort_values("importance", ascending=False)
# Out:
#                 feature  importance
# 2              duration    0.420481
# 38     poutcome_success    0.172472
# 0                   age    0.079567
# 1               balance    0.057749
# 22          housing_yes    0.027378
# 25      contact_unknown    0.023816
# 3              campaign    0.021752
# 35            month_oct    0.020552
# 4              previous    0.020345
# 32            month_mar    0.020303
# 31            month_jun    0.018509
# 36            month_sep    0.015222
# 33            month_may    0.010117
# 16      marital_married    0.006450
# 34            month_nov    0.006198
# 19   education_tertiary    0.006029
# 13       job_technician    0.005790
# 8        job_management    0.005501
# 23             loan_yes    0.004901
# 18  education_secondary    0.004429
# 24    contact_telephone    0.004386
# 17       marital_single    0.004133
# 5       job_blue-collar    0.003875
# 30            month_jul    0.003822
# 39     poutcome_unknown    0.003670
# 26            month_aug    0.003497
# 28            month_feb    0.003337
# 12          job_student    0.003105
# 29            month_jan    0.002968
# 20    education_unknown    0.002858
# 11         job_services    0.002414
# 10    job_self-employed    0.002381
# 27            month_dec    0.002166
# 6      job_entrepreneur    0.001667
# 14       job_unemployed    0.001666
# 7         job_housemaid    0.001620
# 37       poutcome_other    0.001610
# 9           job_retired    0.001589
# 21          default_yes    0.001072
# 15          job_unknown    0.000603
